# %% [markdown]
# <a href="https://colab.research.google.com/github/mushir2004/Generation/blob/main/deblur_GAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, Activation, BatchNormalization, Add, Dropout, LeakyReLU, Conv2DTranspose, Lambda
from tensorflow.keras.models import Model

# Define ReflectionPadding2D if not already defined
class ReflectionPadding2D(tf.keras.layers.Layer):
    def __init__(self, padding=(1, 1), **kwargs):
        self.padding = tuple(padding)
        super(ReflectionPadding2D, self).__init__(**kwargs)

    def compute_output_shape(self, input_shape):
        return (input_shape[0],
                input_shape[1] + 2 * self.padding[0],
                input_shape[2] + 2 * self.padding[1],
                input_shape[3])

    def call(self, x):
        padding_width, padding_height = self.padding
        return tf.pad(x, [[0, 0], [padding_height, padding_height], [padding_width, padding_width], [0, 0]], 'REFLECT')

# Define res_block if not already defined
def res_block(input_tensor, filters, kernel_size=(3, 3), strides=(1, 1), use_dropout=False):
    """
    Instantiate a Keras ResNet Block using the Functional API.
    :param input_tensor: Input tensor
    :param filters: Number of filters to use
    :param kernel_size: Shape of the kernel for the convolution
    :param strides: Shape of the strides for the convolution
    :param use_dropout: Boolean value to determine the use of dropout
    :return: Keras tensor
    """
    x = ReflectionPadding2D((1, 1))(input_tensor)
    x = Conv2D(filters=filters, kernel_size=kernel_size, strides=strides)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    if use_dropout:
        x = Dropout(0.5)(x)

    x = ReflectionPadding2D((1, 1))(x)
    x = Conv2D(filters=filters, kernel_size=kernel_size, strides=strides)(x)
    x = BatchNormalization()(x)

    merged = Add()([input_tensor, x])
    return merged

# Model parameters
ngf = 64
input_nc = 3
output_nc = 3
input_shape_generator = (256, 256, input_nc)
n_blocks_gen = 9

def generator_model():
    """Build generator architecture."""
    inputs = Input(shape=input_shape_generator)

    x = ReflectionPadding2D((3, 3))(inputs)
    x = Conv2D(filters=ngf, kernel_size=(7, 7), padding='valid')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    # Increase filter number
    n_downsampling = 2
    for i in range(n_downsampling):
        mult = 2 ** i
        x = Conv2D(filters=ngf * mult * 2, kernel_size=(3, 3), strides=2, padding='same')(x)
        x = BatchNormalization()(x)
        x = Activation('relu')(x)

    # Apply 9 ResNet blocks
    mult = 2 ** n_downsampling
    for i in range(n_blocks_gen):
        x = res_block(x, ngf * mult, use_dropout=True)

    # Decrease filter number to 3 (RGB)
    for i in range(n_downsampling):
        mult = 2 ** (n_downsampling - i)
        x = Conv2DTranspose(filters=int(ngf * mult / 2), kernel_size=(3, 3), strides=2, padding='same')(x)
        x = BatchNormalization()(x)
        x = Activation('relu')(x)

    x = ReflectionPadding2D((3, 3))(x)
    x = Conv2D(filters=output_nc, kernel_size=(7, 7), padding='valid')(x)
    x = Activation('tanh')(x)

    # Add direct connection from input to output and recenter to [-1, 1]
    outputs = Add()([x, inputs])
    outputs = Lambda(lambda z: z / 2)(outputs)

    model = Model(inputs=inputs, outputs=outputs, name='Generator')
    return model

# Create the generator model
generator = generator_model()

# Print the model summary
generator.summary()
# Out:
# Model: "Generator"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  reflection_padding2d_10 (R  (None, 262, 262, 3)          0         ['input_2[0][0]']
#  eflectionPadding2D)
#
#  conv2d_12 (Conv2D)          (None, 256, 256, 64)         9472      ['reflection_padding2d_10[0][0
#                                                                     ]']
#
#  batch_normalization_11 (Ba  (None, 256, 256, 64)         256       ['conv2d_12[0][0]']
#  tchNormalization)
#
#  activation_7 (Activation)   (None, 256, 256, 64)         0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  conv2d_13 (Conv2D)          (None, 128, 128, 128)        73856     ['activation_7[0][0]']
#
#  batch_normalization_12 (Ba  (None, 128, 128, 128)        512       ['conv2d_13[0][0]']
#  tchNormalization)
#
#  activation_8 (Activation)   (None, 128, 128, 128)        0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  conv2d_14 (Conv2D)          (None, 64, 64, 256)          295168    ['activation_8[0][0]']
#
#  batch_normalization_13 (Ba  (None, 64, 64, 256)          1024      ['conv2d_14[0][0]']
#  tchNormalization)
#
#  activation_9 (Activation)   (None, 64, 64, 256)          0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  reflection_padding2d_11 (R  (None, 66, 66, 256)          0         ['activation_9[0][0]']
#  eflectionPadding2D)
#
#  conv2d_15 (Conv2D)          (None, 64, 64, 256)          590080    ['reflection_padding2d_11[0][0
#                                                                     ]']
#
#  batch_normalization_14 (Ba  (None, 64, 64, 256)          1024      ['conv2d_15[0][0]']
#  tchNormalization)
#
#  activation_10 (Activation)  (None, 64, 64, 256)          0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  dropout_5 (Dropout)         (None, 64, 64, 256)          0         ['activation_10[0][0]']
#
#  reflection_padding2d_12 (R  (None, 66, 66, 256)          0         ['dropout_5[0][0]']
#  eflectionPadding2D)
#
#  conv2d_16 (Conv2D)          (None, 64, 64, 256)          590080    ['reflection_padding2d_12[0][0
#                                                                     ]']
#
#  batch_normalization_15 (Ba  (None, 64, 64, 256)          1024      ['conv2d_16[0][0]']
#  tchNormalization)
#
#  add_5 (Add)                 (None, 64, 64, 256)          0         ['activation_9[0][0]',
#                                                                      'batch_normalization_15[0][0]
#                                                                     ']
#
#  reflection_padding2d_13 (R  (None, 66, 66, 256)          0         ['add_5[0][0]']
#  eflectionPadding2D)
#
#  conv2d_17 (Conv2D)          (None, 64, 64, 256)          590080    ['reflection_padding2d_13[0][0
#                                                                     ]']
#
#  batch_normalization_16 (Ba  (None, 64, 64, 256)          1024      ['conv2d_17[0][0]']
#  tchNormalization)
#
#  activation_11 (Activation)  (None, 64, 64, 256)          0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  dropout_6 (Dropout)         (None, 64, 64, 256)          0         ['activation_11[0][0]']
#
#  reflection_padding2d_14 (R  (None, 66, 66, 256)          0         ['dropout_6[0][0]']
#  eflectionPadding2D)
#
#  conv2d_18 (Conv2D)          (None, 64, 64, 256)          590080    ['reflection_padding2d_14[0][0
#                                                                     ]']
#
#  batch_normalization_17 (Ba  (None, 64, 64, 256)          1024      ['conv2d_18[0][0]']
#  tchNormalization)
#
#  add_6 (Add)                 (None, 64, 64, 256)          0         ['add_5[0][0]',
#                                                                      'batch_normalization_17[0][0]
#                                                                     ']
#
#  reflection_padding2d_15 (R  (None, 66, 66, 256)          0         ['add_6[0][0]']
#  eflectionPadding2D)
#
#  conv2d_19 (Conv2D)          (None, 64, 64, 256)          590080    ['reflection_padding2d_15[0][0
#                                                                     ]']
#
#  batch_normalization_18 (Ba  (None, 64, 64, 256)          1024      ['conv2d_19[0][0]']
#  tchNormalization)
#
#  activation_12 (Activation)  (None, 64, 64, 256)          0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  dropout_7 (Dropout)         (None, 64, 64, 256)          0         ['activation_12[0][0]']
#
#  reflection_padding2d_16 (R  (None, 66, 66, 256)          0         ['dropout_7[0][0]']
#  eflectionPadding2D)
#
#  conv2d_20 (Conv2D)          (None, 64, 64, 256)          590080    ['reflection_padding2d_16[0][0
#                                                                     ]']
#
#  batch_normalization_19 (Ba  (None, 64, 64, 256)          1024      ['conv2d_20[0][0]']
#  tchNormalization)
#
#  add_7 (Add)                 (None, 64, 64, 256)          0         ['add_6[0][0]',
#                                                                      'batch_normalization_19[0][0]
#                                                                     ']
#
#  reflection_padding2d_17 (R  (None, 66, 66, 256)          0         ['add_7[0][0]']
#  eflectionPadding2D)
#
#  conv2d_21 (Conv2D)          (None, 64, 64, 256)          590080    ['reflection_padding2d_17[0][0
#                                                                     ]']
#
#  batch_normalization_20 (Ba  (None, 64, 64, 256)          1024      ['conv2d_21[0][0]']
#  tchNormalization)
#
#  activation_13 (Activation)  (None, 64, 64, 256)          0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  dropout_8 (Dropout)         (None, 64, 64, 256)          0         ['activation_13[0][0]']
#
#  reflection_padding2d_18 (R  (None, 66, 66, 256)          0         ['dropout_8[0][0]']
#  eflectionPadding2D)
#
#  conv2d_22 (Conv2D)          (None, 64, 64, 256)          590080    ['reflection_padding2d_18[0][0
#                                                                     ]']
#
#  batch_normalization_21 (Ba  (None, 64, 64, 256)          1024      ['conv2d_22[0][0]']
#  tchNormalization)
#
#  add_8 (Add)                 (None, 64, 64, 256)          0         ['add_7[0][0]',
#                                                                      'batch_normalization_21[0][0]
#                                                                     ']
#
#  reflection_padding2d_19 (R  (None, 66, 66, 256)          0         ['add_8[0][0]']
#  eflectionPadding2D)
#
#  conv2d_23 (Conv2D)          (None, 64, 64, 256)          590080    ['reflection_padding2d_19[0][0
#                                                                     ]']
#
#  batch_normalization_22 (Ba  (None, 64, 64, 256)          1024      ['conv2d_23[0][0]']
#  tchNormalization)
#
#  activation_14 (Activation)  (None, 64, 64, 256)          0         ['batch_normalization_22[0][0]
#                                                                     ']
#
#  dropout_9 (Dropout)         (None, 64, 64, 256)          0         ['activation_14[0][0]']
#
#  reflection_padding2d_20 (R  (None, 66, 66, 256)          0         ['dropout_9[0][0]']
#  eflectionPadding2D)
#
#  conv2d_24 (Conv2D)          (None, 64, 64, 256)          590080    ['reflection_padding2d_20[0][0
#                                                                     ]']
#
#  batch_normalization_23 (Ba  (None, 64, 64, 256)          1024      ['conv2d_24[0][0]']
#  tchNormalization)
#
#  add_9 (Add)                 (None, 64, 64, 256)          0         ['add_8[0][0]',
#                                                                      'batch_normalization_23[0][0]
#                                                                     ']
#
#  reflection_padding2d_21 (R  (None, 66, 66, 256)          0         ['add_9[0][0]']
#  eflectionPadding2D)
#
#  conv2d_25 (Conv2D)          (None, 64, 64, 256)          590080    ['reflection_padding2d_21[0][0
#                                                                     ]']
#
#  batch_normalization_24 (Ba  (None, 64, 64, 256)          1024      ['conv2d_25[0][0]']
#  tchNormalization)
#
#  activation_15 (Activation)  (None, 64, 64, 256)          0         ['batch_normalization_24[0][0]
#                                                                     ']
#
#  dropout_10 (Dropout)        (None, 64, 64, 256)          0         ['activation_15[0][0]']
#
#  reflection_padding2d_22 (R  (None, 66, 66, 256)          0         ['dropout_10[0][0]']
#  eflectionPadding2D)
#
#  conv2d_26 (Conv2D)          (None, 64, 64, 256)          590080    ['reflection_padding2d_22[0][0
#                                                                     ]']
#
#  batch_normalization_25 (Ba  (None, 64, 64, 256)          1024      ['conv2d_26[0][0]']
#  tchNormalization)
#
#  add_10 (Add)                (None, 64, 64, 256)          0         ['add_9[0][0]',
#                                                                      'batch_normalization_25[0][0]
#                                                                     ']
#
#  reflection_padding2d_23 (R  (None, 66, 66, 256)          0         ['add_10[0][0]']
#  eflectionPadding2D)
#
#  conv2d_27 (Conv2D)          (None, 64, 64, 256)          590080    ['reflection_padding2d_23[0][0
#                                                                     ]']
#
#  batch_normalization_26 (Ba  (None, 64, 64, 256)          1024      ['conv2d_27[0][0]']
#  tchNormalization)
#
#  activation_16 (Activation)  (None, 64, 64, 256)          0         ['batch_normalization_26[0][0]
#                                                                     ']
#
#  dropout_11 (Dropout)        (None, 64, 64, 256)          0         ['activation_16[0][0]']
#
#  reflection_padding2d_24 (R  (None, 66, 66, 256)          0         ['dropout_11[0][0]']
#  eflectionPadding2D)
#
#  conv2d_28 (Conv2D)          (None, 64, 64, 256)          590080    ['reflection_padding2d_24[0][0
#                                                                     ]']
#
#  batch_normalization_27 (Ba  (None, 64, 64, 256)          1024      ['conv2d_28[0][0]']
#  tchNormalization)
#
#  add_11 (Add)                (None, 64, 64, 256)          0         ['add_10[0][0]',
#                                                                      'batch_normalization_27[0][0]
#                                                                     ']
#
#  reflection_padding2d_25 (R  (None, 66, 66, 256)          0         ['add_11[0][0]']
#  eflectionPadding2D)
#
#  conv2d_29 (Conv2D)          (None, 64, 64, 256)          590080    ['reflection_padding2d_25[0][0
#                                                                     ]']
#
#  batch_normalization_28 (Ba  (None, 64, 64, 256)          1024      ['conv2d_29[0][0]']
#  tchNormalization)
#
#  activation_17 (Activation)  (None, 64, 64, 256)          0         ['batch_normalization_28[0][0]
#                                                                     ']
#
#  dropout_12 (Dropout)        (None, 64, 64, 256)          0         ['activation_17[0][0]']
#
#  reflection_padding2d_26 (R  (None, 66, 66, 256)          0         ['dropout_12[0][0]']
#  eflectionPadding2D)
#
#  conv2d_30 (Conv2D)          (None, 64, 64, 256)          590080    ['reflection_padding2d_26[0][0
#                                                                     ]']
#
#  batch_normalization_29 (Ba  (None, 64, 64, 256)          1024      ['conv2d_30[0][0]']
#  tchNormalization)
#
#  add_12 (Add)                (None, 64, 64, 256)          0         ['add_11[0][0]',
#                                                                      'batch_normalization_29[0][0]
#                                                                     ']
#
#  reflection_padding2d_27 (R  (None, 66, 66, 256)          0         ['add_12[0][0]']
#  eflectionPadding2D)
#
#  conv2d_31 (Conv2D)          (None, 64, 64, 256)          590080    ['reflection_padding2d_27[0][0
#                                                                     ]']
#
#  batch_normalization_30 (Ba  (None, 64, 64, 256)          1024      ['conv2d_31[0][0]']
#  tchNormalization)
#
#  activation_18 (Activation)  (None, 64, 64, 256)          0         ['batch_normalization_30[0][0]
#                                                                     ']
#
#  dropout_13 (Dropout)        (None, 64, 64, 256)          0         ['activation_18[0][0]']
#
#  reflection_padding2d_28 (R  (None, 66, 66, 256)          0         ['dropout_13[0][0]']
#  eflectionPadding2D)
#
#  conv2d_32 (Conv2D)          (None, 64, 64, 256)          590080    ['reflection_padding2d_28[0][0
#                                                                     ]']
#
#  batch_normalization_31 (Ba  (None, 64, 64, 256)          1024      ['conv2d_32[0][0]']
#  tchNormalization)
#
#  add_13 (Add)                (None, 64, 64, 256)          0         ['add_12[0][0]',
#                                                                      'batch_normalization_31[0][0]
#                                                                     ']
#
#  conv2d_transpose (Conv2DTr  (None, 128, 128, 128)        295040    ['add_13[0][0]']
#  anspose)
#
#  batch_normalization_32 (Ba  (None, 128, 128, 128)        512       ['conv2d_transpose[0][0]']
#  tchNormalization)
#
#  activation_19 (Activation)  (None, 128, 128, 128)        0         ['batch_normalization_32[0][0]
#                                                                     ']
#
#  conv2d_transpose_1 (Conv2D  (None, 256, 256, 64)         73792     ['activation_19[0][0]']
#  Transpose)
#
#  batch_normalization_33 (Ba  (None, 256, 256, 64)         256       ['conv2d_transpose_1[0][0]']
#  tchNormalization)
#
#  activation_20 (Activation)  (None, 256, 256, 64)         0         ['batch_normalization_33[0][0]
#                                                                     ']
#
#  reflection_padding2d_29 (R  (None, 262, 262, 64)         0         ['activation_20[0][0]']
#  eflectionPadding2D)
#
#  conv2d_33 (Conv2D)          (None, 256, 256, 3)          9411      ['reflection_padding2d_29[0][0
#                                                                     ]']
#
#  activation_21 (Activation)  (None, 256, 256, 3)          0         ['conv2d_33[0][0]']
#
#  add_14 (Add)                (None, 256, 256, 3)          0         ['activation_21[0][0]',
#                                                                      'input_2[0][0]']
#
#  lambda (Lambda)             (None, 256, 256, 3)          0         ['add_14[0][0]']
#
# ==================================================================================================
# Total params: 11399171 (43.48 MB)
# Trainable params: 11388675 (43.44 MB)
# Non-trainable params: 10496 (41.00 KB)
# __________________________________________________________________________________________________
